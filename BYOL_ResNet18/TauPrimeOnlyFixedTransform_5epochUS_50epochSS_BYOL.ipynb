# %%
import torch
from torchvision.datasets import STL10 as STL10
import torchvision.transforms as transforms
from torch.utils.data import random_split
import torchvision


from torch.utils.data import Dataset, DataLoader

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import multiprocessing
import numpy as np
import matplotlib.pyplot as plt

import os
import random
from IPython.display import clear_output
from torchsummary import summary
import time
import pandas as pd
from copy import deepcopy
from tqdm import tqdm

#All images are 3x96x96
image_size = 96
#Example batch size
batch_size = 32
#Define the chosen model type
chosen_model = torchvision.models.resnet18()

# %%
#Set device to GPU_indx if GPU is avaliable
GPU_indx = 0
device = torch.device(GPU_indx if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %% [markdown]
# <h3>Create training and validation split</h3>

# %%
dataset_dir = 'dataset_dir/'

#Load train and validation sets
trainval_set = STL10(dataset_dir, split='train', transform=transforms.ToTensor(), download=True)

#Use 10% of data for training - simulating low data scenario
num_train = int(len(trainval_set)*0.1)

#Split data into train/val sets
torch.manual_seed(0) #Set torch's random seed so that random split of data is reproducible
train_set, val_set = random_split(trainval_set, [num_train, len(trainval_set)-num_train])

#Load test set
test_set = STL10(dataset_dir, split='test', transform=transforms.ToTensor(), download=True)
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to dataset_dir/stl10_binary.tar.gz
#   0%|          | 0/2640397119 [00:00<?, ?it/s]
# Extracting dataset_dir/stl10_binary.tar.gz to dataset_dir/
# Files already downloaded and verified

# %% [markdown]
# <h3>Get the unlabelled data</h3>

# %%
unlabelled_set = STL10(dataset_dir, split='unlabeled', transform=transforms.ToTensor(), download=True)
# Out:
# Files already downloaded and verified

# %% [markdown]
# <h3>Create the four dataloaders</h3>

# %%
train_loader = torch.utils.data.DataLoader(train_set, shuffle=True, batch_size=batch_size)
unlabelled_loader = torch.utils.data.DataLoader(unlabelled_set, shuffle=True, batch_size=batch_size)

valid_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size)
test_loader  = torch.utils.data.DataLoader(test_set, batch_size=batch_size)

# %%
#This Function will allow us to scale an image's pixel values to a value between 0 and 1
#It will undo the Normalisation that the Dataset performs
def normalize_img(img):
    mins = img.min(0, keepdims = True).min(1, keepdims = True)
    maxs = img.max(0, keepdims = True).max(1, keepdims = True)
    return (img - mins)/(maxs - mins)

# %%
plt.figure(figsize = (20,10))
images, labels = next(iter(train_loader))
out = torchvision.utils.make_grid(images[0:8])
plt.imshow(normalize_img(out.numpy().transpose((1, 2, 0))))

# %%
class SupervisedModel():
    def __init__(self, encoder):
        self.model = encoder.cuda()

    @staticmethod
    def count_correct(
        y_pred: torch.Tensor,
        y_true: torch.Tensor
    ) -> torch.Tensor:
        """
        Returns the number of correct predictions
        """
        preds = torch.argmax(y_pred, dim=1)
        return (preds == y_true).float().sum()


    def validate_model(
        self,
        loss_fn, 
        dataloader: DataLoader
    ):
        """
        Validates given model with given loss function on given DataLoader
        """
        loss = 0
        correct = 0
        all = 0
        with torch.no_grad():
            for X_batch, y_batch in dataloader:
                X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
                y_pred = self.model(X_batch)
                all += len(y_pred)
                loss += loss_fn(y_pred, y_batch)
                correct += SupervisedModel.count_correct(y_pred, y_batch)
        return loss / all, correct / all


    def train_model(
        self,
        optimiser: optim.Optimizer,
        loss_fn,
        train_dl: DataLoader,
    ):
        """
        Trains given model with given loss function on given DataLoader
        """
        self.model.train()

        for X_batch, y_batch in train_dl:
            X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            y_pred = self.model(X_batch)
            loss = loss_fn(y_pred, y_batch)

            loss.backward()
            optimiser.step()
            optimiser.zero_grad() 

        self.model.eval() 

    def fit(
        self,
        loss_fn,
        train_dl: DataLoader,
        val_dl: DataLoader,
        test_dl = DataLoader,
        epochs=50
    ) -> dict:
        """
        Trains model and validates on training and validation data
        """
        results = {"train_loss": [], "train_acc": [], "val_loss": [],
                   "val_acc": [], "test_loss": [], "test_acc": []}

        optimiser = optim.AdamW(self.model.parameters())  

        for epoch in range(epochs):
            start = time.time()

            self.train_model(optimiser, loss_fn, train_dl)
            train_loss, train_acc = self.validate_model(loss_fn, train_dl) 
            val_loss, val_acc = self.validate_model(loss_fn, val_dl)
            test_loss, test_acc = self.validate_model(loss_fn, test_dl)

            print(f"Epoch {epoch + 1}: Training loss = {train_loss:.3f} "
             f"(acc: {train_acc:.3f}), Validation loss = {val_loss:.3f} "
             f"(acc: {val_acc:.3f}), Testing loss = {test_loss:.3f} "
             f"(acc: {test_acc:.3f}), time {time.time() - start:.1f}s")
            results["train_loss"].append(float(train_loss))
            results["train_acc"].append(float(train_acc))
            results["val_loss"].append(float(val_loss))
            results["val_acc"].append(float(val_acc))
            results["test_loss"].append(float(test_loss))
            results["test_acc"].append(float(test_acc))

        return results

def evaluate_baseline():
    encoder = chosen_model
    num_ftrs = encoder.fc.in_features
    #redefine the last fc layer with a linear layer with 10 ouputs, this layer's weights will be randomly initialised
    encoder.fc = nn.Linear(num_ftrs, 10)

    baseline_model = SupervisedModel(encoder)

    loss_fn = nn.CrossEntropyLoss(reduction='sum')

    return baseline_model.fit(loss_fn, train_loader, valid_loader, test_loader)

history_baseline = evaluate_baseline()
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448265233/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch 1: Training loss = 9.840 (acc: 0.106), Validation loss = 9.910 (acc: 0.099), Testing loss = 9.865 (acc: 0.100), time 9.6s
# Epoch 2: Training loss = 1.787 (acc: 0.330), Validation loss = 2.098 (acc: 0.234), Testing loss = 2.082 (acc: 0.244), time 6.8s
# Epoch 3: Training loss = 1.110 (acc: 0.652), Validation loss = 2.148 (acc: 0.277), Testing loss = 2.135 (acc: 0.286), time 6.9s
# Epoch 4: Training loss = 1.372 (acc: 0.526), Validation loss = 3.098 (acc: 0.193), Testing loss = 3.093 (acc: 0.190), time 6.9s
# Epoch 5: Training loss = 0.699 (acc: 0.762), Validation loss = 2.849 (acc: 0.304), Testing loss = 2.797 (acc: 0.320), time 6.8s
# Epoch 6: Training loss = 1.184 (acc: 0.628), Validation loss = 3.316 (acc: 0.266), Testing loss = 3.332 (acc: 0.274), time 6.8s
# Epoch 7: Training loss = 1.242 (acc: 0.626), Validation loss = 3.252 (acc: 0.281), Testing loss = 3.255 (acc: 0.278), time 6.7s
# Epoch 8: Training loss = 0.475 (acc: 0.840), Validation loss = 3.077 (acc: 0.285), Testing loss = 3.137 (acc: 0.277), time 6.7s
# Epoch 9: Training loss = 0.249 (acc: 0.924), Validation loss = 3.123 (acc: 0.313), Testing loss = 3.130 (acc: 0.317), time 6.8s
# Epoch 10: Training loss = 0.157 (acc: 0.952), Validation loss = 2.854 (acc: 0.324), Testing loss = 2.886 (acc: 0.330), time 6.9s
# Epoch 11: Training loss = 0.228 (acc: 0.934), Validation loss = 3.254 (acc: 0.295), Testing loss = 3.172 (acc: 0.303), time 6.7s
# Epoch 12: Training loss = 0.120 (acc: 0.960), Validation loss = 3.091 (acc: 0.329), Testing loss = 3.108 (acc: 0.328), time 6.8s
# Epoch 13: Training loss = 0.209 (acc: 0.926), Validation loss = 3.587 (acc: 0.306), Testing loss = 3.609 (acc: 0.298), time 6.8s
# Epoch 14: Training loss = 0.045 (acc: 0.984), Validation loss = 3.116 (acc: 0.343), Testing loss = 3.101 (acc: 0.341), time 6.9s
# Epoch 15: Training loss = 0.213 (acc: 0.932), Validation loss = 3.403 (acc: 0.296), Testing loss = 3.346 (acc: 0.301), time 6.9s
# Epoch 16: Training loss = 0.132 (acc: 0.958), Validation loss = 3.216 (acc: 0.310), Testing loss = 3.190 (acc: 0.321), time 6.7s
# Epoch 17: Training loss = 0.623 (acc: 0.826), Validation loss = 3.542 (acc: 0.279), Testing loss = 3.529 (acc: 0.287), time 6.8s
# Epoch 18: Training loss = 0.069 (acc: 0.978), Validation loss = 3.105 (acc: 0.316), Testing loss = 3.084 (acc: 0.321), time 6.8s
# Epoch 19: Training loss = 0.009 (acc: 1.000), Validation loss = 3.009 (acc: 0.343), Testing loss = 3.001 (acc: 0.351), time 6.8s
# Epoch 20: Training loss = 0.010 (acc: 0.998), Validation loss = 3.249 (acc: 0.323), Testing loss = 3.273 (acc: 0.326), time 6.9s
# Epoch 21: Training loss = 0.002 (acc: 1.000), Validation loss = 3.155 (acc: 0.341), Testing loss = 3.164 (acc: 0.347), time 6.8s
# Epoch 22: Training loss = 0.001 (acc: 1.000), Validation loss = 3.044 (acc: 0.347), Testing loss = 3.060 (acc: 0.351), time 6.8s
# Epoch 23: Training loss = 0.001 (acc: 1.000), Validation loss = 3.040 (acc: 0.355), Testing loss = 3.043 (acc: 0.357), time 6.8s
# Epoch 24: Training loss = 0.002 (acc: 1.000), Validation loss = 3.028 (acc: 0.348), Testing loss = 3.043 (acc: 0.354), time 6.9s
# Epoch 25: Training loss = 0.000 (acc: 1.000), Validation loss = 3.052 (acc: 0.350), Testing loss = 3.079 (acc: 0.356), time 6.8s
# Epoch 26: Training loss = 0.000 (acc: 1.000), Validation loss = 2.997 (acc: 0.357), Testing loss = 3.016 (acc: 0.365), time 6.8s
# Epoch 27: Training loss = 0.000 (acc: 1.000), Validation loss = 2.997 (acc: 0.358), Testing loss = 3.011 (acc: 0.366), time 6.8s
# Epoch 28: Training loss = 0.000 (acc: 1.000), Validation loss = 2.999 (acc: 0.358), Testing loss = 3.009 (acc: 0.366), time 6.9s
# Epoch 29: Training loss = 0.000 (acc: 1.000), Validation loss = 2.991 (acc: 0.359), Testing loss = 3.005 (acc: 0.368), time 6.9s
# Epoch 30: Training loss = 0.000 (acc: 1.000), Validation loss = 2.979 (acc: 0.358), Testing loss = 2.994 (acc: 0.368), time 6.8s
# Epoch 31: Training loss = 0.000 (acc: 1.000), Validation loss = 2.966 (acc: 0.360), Testing loss = 2.982 (acc: 0.371), time 6.9s
# Epoch 32: Training loss = 0.000 (acc: 1.000), Validation loss = 2.950 (acc: 0.359), Testing loss = 2.968 (acc: 0.371), time 6.7s
# Epoch 33: Training loss = 0.000 (acc: 1.000), Validation loss = 2.967 (acc: 0.362), Testing loss = 2.982 (acc: 0.373), time 6.9s
# Epoch 34: Training loss = 0.000 (acc: 1.000), Validation loss = 2.988 (acc: 0.358), Testing loss = 3.003 (acc: 0.370), time 6.8s
# Epoch 35: Training loss = 0.000 (acc: 1.000), Validation loss = 2.966 (acc: 0.360), Testing loss = 2.981 (acc: 0.371), time 6.8s
# Epoch 36: Training loss = 0.000 (acc: 1.000), Validation loss = 2.971 (acc: 0.363), Testing loss = 2.986 (acc: 0.374), time 6.7s
# Epoch 37: Training loss = 0.000 (acc: 1.000), Validation loss = 2.970 (acc: 0.363), Testing loss = 2.985 (acc: 0.373), time 6.7s
# Epoch 38: Training loss = 0.000 (acc: 1.000), Validation loss = 2.984 (acc: 0.362), Testing loss = 3.002 (acc: 0.373), time 6.9s
# Epoch 39: Training loss = 0.000 (acc: 1.000), Validation loss = 2.971 (acc: 0.363), Testing loss = 2.989 (acc: 0.375), time 6.8s
# Epoch 40: Training loss = 0.000 (acc: 1.000), Validation loss = 2.961 (acc: 0.363), Testing loss = 2.979 (acc: 0.375), time 6.9s
# Epoch 41: Training loss = 0.000 (acc: 1.000), Validation loss = 2.969 (acc: 0.364), Testing loss = 2.986 (acc: 0.373), time 6.8s
# Epoch 42: Training loss = 0.000 (acc: 1.000), Validation loss = 2.960 (acc: 0.364), Testing loss = 2.978 (acc: 0.375), time 6.9s
# Epoch 43: Training loss = 0.000 (acc: 1.000), Validation loss = 2.976 (acc: 0.366), Testing loss = 2.995 (acc: 0.373), time 7.0s
# Epoch 44: Training loss = 0.000 (acc: 1.000), Validation loss = 2.968 (acc: 0.364), Testing loss = 2.986 (acc: 0.372), time 6.8s
# Epoch 45: Training loss = 0.000 (acc: 1.000), Validation loss = 2.976 (acc: 0.364), Testing loss = 2.995 (acc: 0.375), time 6.8s
# Epoch 46: Training loss = 0.000 (acc: 1.000), Validation loss = 2.996 (acc: 0.367), Testing loss = 3.016 (acc: 0.374), time 6.7s
# Epoch 47: Training loss = 0.000 (acc: 1.000), Validation loss = 2.968 (acc: 0.365), Testing loss = 2.987 (acc: 0.373), time 6.9s
# Epoch 48: Training loss = 0.000 (acc: 1.000), Validation loss = 2.966 (acc: 0.366), Testing loss = 2.987 (acc: 0.374), time 6.9s
# Epoch 49: Training loss = 0.000 (acc: 1.000), Validation loss = 2.980 (acc: 0.367), Testing loss = 2.997 (acc: 0.373), time 6.9s
# Epoch 50: Training loss = 0.000 (acc: 1.000), Validation loss = 2.982 (acc: 0.368), Testing loss = 3.001 (acc: 0.373), time 6.9s

# %%
class Solarization(nn.Module):
    def __call__(self, x):
        return transforms.functional.solarize(x, threshold=0.5)

def augmentation_tau_prime(p_blur=0.1, p_solarize=0.2):
    return nn.Sequential(
        transforms.RandomResizedCrop(96),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ColorJitter(brightness=(0,0.4), contrast=(0,0.4), saturation=(0,0.2), hue=(0,0.1)),
        transforms.Grayscale(num_output_channels=3),
        transforms.GaussianBlur(3),
        Solarization(),
        transforms.Normalize(
            mean=torch.tensor([0.485, 0.456, 0.406]),
            std=torch.tensor([0.229, 0.224, 0.225]),
        )
    )

def augmentation_tau():
    return nn.Sequential(
        transforms.Normalize(
            mean=torch.tensor([0.485, 0.456, 0.406]),
            std=torch.tensor([0.229, 0.224, 0.225]),
        )
    )

# %%
class BYOL(nn.Module):
    def __init__(self,
                 model,
                 augmentation,
                 augmentation_prime,
                 encoder_out_shape = 1000,
                 projection_size = 256,
                 tau = 0.999):
        super().__init__()       
        self.encoder_online = model
        self.projector_online = BYOL.mlp(encoder_out_shape, projection_size) # Create a network for projection
        self.online_common = nn.Sequential(self.encoder_online,
                                           self.projector_online)  # Encoder and projector are the same for target and online network
        
        self.predictor_online = BYOL.mlp(projection_size, projection_size)
        self.online = nn.Sequential(self.online_common, self.predictor_online) # Whole online network

        self.target = deepcopy(self.online_common) # Target network without prediction head

        self.tau = tau # Tau for moving exponential average
        self.augmentation = augmentation
        self.augmentation_prime = augmentation_prime

        self.loss_fn = nn.MSELoss(reduction="sum") # Loss function for comparision of outputs of two networks
        self.optimiser = optim.AdamW(self.online.parameters()) # Optimizer, diffrent than in paper

    @staticmethod
    def mlp(dim_in: int,
            projection_size: int,
            hidden_size: int = 4096
            ) -> nn.Module:
        return nn.Sequential(
                nn.Linear(dim_in, hidden_size), # a linear layer with output size 4096
                nn.BatchNorm1d(hidden_size), # followed by batch normalization,
                nn.ReLU(inplace=True), # rectified linear units (ReLU),
                nn.Linear(hidden_size, projection_size)) # and a final linear layer with output dimension 256

    def fit(self,
            train_dl: DataLoader,
            val_dl: DataLoader,
            epochs: int
        ) -> dict:
        results = {"train_loss": [], "val_loss": []}

        for epoch in range(epochs):
            start = time.time()
            self.train_one_epoch(train_dl) # Train (fit) model on unlabelled data

            train_loss = self.validate(train_dl) # Validate on unlabelled train data
            val_loss = self.validate(val_dl) # Validate on validation data (labels omitted)

            # Print results
            print(f"Epoch {epoch+1}: train loss = {train_loss:.4f}, validation "
                f"loss = {val_loss:.4f}, time "
                f"{((time.time() - start)/60):.1f} min")
            results["train_loss"].append(float(train_loss))
            results["val_loss"].append(float(val_loss))

        return results

    def train_one_epoch(self,
                        train_dl: DataLoader
        ):
        self.online.train()
        self.target.train()

        for X_batch, y_batch in tqdm(train_dl):
            X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            loss = self.forward(X_batch)

            loss.backward()
            self.optimiser.step()
            self.optimiser.zero_grad() 

            self.update_target()

        self.target.eval()
        self.online.eval()

        
    def forward(self,
                X_batch: torch.Tensor
        ) -> torch.Tensor:
        with torch.no_grad():
            v, v_prime = self.augmentation(X_batch), self.augmentation_prime(X_batch)

        pred1, pred2 = self.online(v), self.online(v_prime)
        pred1, pred2 = F.normalize(pred1), F.normalize(pred2)
        with torch.no_grad():
            z1, z2 = self.target(v_prime), self.target(v)
            z1, z2 = F.normalize(z1), F.normalize(z2)

        return self.loss_fn(pred1, z1) + self.loss_fn(pred2, z2)
    
    
    def update_target(self):
        for p_online, p_target in zip(self.online_common.parameters(),
                                      self.target.parameters()):
            p_target.data = self.tau * p_target.data + (1 - self.tau) * p_online.data


    def validate(self,
                 dataloader: DataLoader
        ) -> torch.Tensor:
        loss = 0
        all = 0
        for X_batch, y_batch in tqdm(dataloader):
            X_batch, y_batch = X_batch.cuda(), y_batch.cuda()
            with torch.no_grad():
                loss += self.forward(X_batch)
            all += len(X_batch)
        return loss / all


encoder = torchvision.models.resnet18()
num_ftrs = encoder.fc.in_features
encoder.fc = nn.Identity()

model = BYOL(encoder, augmentation_tau(), augmentation_tau_prime(),
                encoder_out_shape = num_ftrs).cuda()
history_unsupervised = model.fit(unlabelled_loader, train_loader, 5)
# Out:
# 100%|██████████| 3125/3125 [04:35<00:00, 11.34it/s]
# 100%|██████████| 3125/3125 [01:55<00:00, 27.01it/s]
# 100%|██████████| 16/16 [00:00<00:00, 27.20it/s]
# Epoch 1: train loss = 3.5959, validation loss = 3.6362, time 6.5 min
# 100%|██████████| 3125/3125 [04:35<00:00, 11.34it/s]
# 100%|██████████| 3125/3125 [01:55<00:00, 27.00it/s]
# 100%|██████████| 16/16 [00:00<00:00, 27.22it/s]
# Epoch 2: train loss = 4.2835, validation loss = 4.3195, time 6.5 min
# 100%|██████████| 3125/3125 [04:35<00:00, 11.35it/s]
# 100%|██████████| 3125/3125 [01:55<00:00, 26.96it/s]
# 100%|██████████| 16/16 [00:00<00:00, 27.12it/s]
# Epoch 3: train loss = 4.8499, validation loss = 4.8783, time 6.5 min
# 100%|██████████| 3125/3125 [04:35<00:00, 11.35it/s]
# 100%|██████████| 3125/3125 [01:55<00:00, 27.01it/s]
# 100%|██████████| 16/16 [00:00<00:00, 27.28it/s]
# Epoch 4: train loss = 4.8582, validation loss = 4.9437, time 6.5 min
# 100%|██████████| 3125/3125 [04:35<00:00, 11.35it/s]
# 100%|██████████| 3125/3125 [01:55<00:00, 26.99it/s]
# 100%|██████████| 16/16 [00:00<00:00, 27.16it/s]
# Epoch 5: train loss = 4.9890, validation loss = 5.0006, time 6.5 min

# %%
state_dict = model.encoder_online.state_dict()
encoder_post = chosen_model
num_ftrs_post = encoder_post.fc.in_features
encoder_post.fc = nn.Identity()
encoder_post.load_state_dict(state_dict)

encoder_post.fc = nn.Linear(num_ftrs_post, 10)

semi_sup_model = SupervisedModel(encoder_post)
loss_fn = nn.CrossEntropyLoss(reduction='sum')
history = semi_sup_model.fit(loss_fn, train_loader, valid_loader, test_loader)
# Out:
# Epoch 1: Training loss = 2.360 (acc: 0.154), Validation loss = 2.363 (acc: 0.152), Testing loss = 2.366 (acc: 0.146), time 6.6s
# Epoch 2: Training loss = 2.033 (acc: 0.274), Validation loss = 2.090 (acc: 0.250), Testing loss = 2.092 (acc: 0.253), time 6.6s
# Epoch 3: Training loss = 1.871 (acc: 0.322), Validation loss = 1.972 (acc: 0.293), Testing loss = 1.969 (acc: 0.287), time 6.6s
# Epoch 4: Training loss = 1.755 (acc: 0.360), Validation loss = 1.871 (acc: 0.314), Testing loss = 1.864 (acc: 0.316), time 6.7s
# Epoch 5: Training loss = 1.629 (acc: 0.394), Validation loss = 1.803 (acc: 0.323), Testing loss = 1.800 (acc: 0.315), time 6.6s
# Epoch 6: Training loss = 1.812 (acc: 0.340), Validation loss = 2.033 (acc: 0.275), Testing loss = 2.027 (acc: 0.273), time 6.5s
# Epoch 7: Training loss = 1.483 (acc: 0.448), Validation loss = 1.703 (acc: 0.341), Testing loss = 1.709 (acc: 0.338), time 6.6s
# Epoch 8: Training loss = 1.401 (acc: 0.500), Validation loss = 1.678 (acc: 0.343), Testing loss = 1.680 (acc: 0.353), time 6.6s
# Epoch 9: Training loss = 1.507 (acc: 0.460), Validation loss = 1.862 (acc: 0.323), Testing loss = 1.872 (acc: 0.323), time 6.6s
# Epoch 10: Training loss = 1.267 (acc: 0.552), Validation loss = 1.684 (acc: 0.354), Testing loss = 1.689 (acc: 0.356), time 6.6s
# Epoch 11: Training loss = 1.199 (acc: 0.582), Validation loss = 1.659 (acc: 0.373), Testing loss = 1.670 (acc: 0.365), time 6.5s
# Epoch 12: Training loss = 1.177 (acc: 0.584), Validation loss = 1.767 (acc: 0.354), Testing loss = 1.771 (acc: 0.356), time 6.6s
# Epoch 13: Training loss = 1.111 (acc: 0.582), Validation loss = 1.765 (acc: 0.348), Testing loss = 1.773 (acc: 0.349), time 6.5s
# Epoch 14: Training loss = 1.010 (acc: 0.662), Validation loss = 1.769 (acc: 0.354), Testing loss = 1.765 (acc: 0.357), time 6.6s
# Epoch 15: Training loss = 0.880 (acc: 0.752), Validation loss = 1.792 (acc: 0.356), Testing loss = 1.793 (acc: 0.355), time 6.5s
# Epoch 16: Training loss = 0.842 (acc: 0.712), Validation loss = 1.847 (acc: 0.355), Testing loss = 1.847 (acc: 0.367), time 6.5s
# Epoch 17: Training loss = 0.793 (acc: 0.726), Validation loss = 1.980 (acc: 0.344), Testing loss = 2.008 (acc: 0.342), time 6.6s
# Epoch 18: Training loss = 0.580 (acc: 0.844), Validation loss = 2.034 (acc: 0.348), Testing loss = 2.033 (acc: 0.346), time 6.7s
# Epoch 19: Training loss = 0.466 (acc: 0.888), Validation loss = 2.026 (acc: 0.356), Testing loss = 2.028 (acc: 0.355), time 6.8s
# Epoch 20: Training loss = 0.455 (acc: 0.876), Validation loss = 2.205 (acc: 0.330), Testing loss = 2.187 (acc: 0.337), time 6.6s
# Epoch 21: Training loss = 0.244 (acc: 0.964), Validation loss = 2.287 (acc: 0.359), Testing loss = 2.281 (acc: 0.361), time 6.7s
# Epoch 22: Training loss = 0.227 (acc: 0.950), Validation loss = 2.530 (acc: 0.345), Testing loss = 2.474 (acc: 0.352), time 6.8s
# Epoch 23: Training loss = 0.140 (acc: 0.990), Validation loss = 2.492 (acc: 0.350), Testing loss = 2.476 (acc: 0.342), time 6.6s
# Epoch 24: Training loss = 0.092 (acc: 0.984), Validation loss = 2.717 (acc: 0.350), Testing loss = 2.673 (acc: 0.356), time 6.9s
# Epoch 25: Training loss = 0.056 (acc: 0.998), Validation loss = 2.777 (acc: 0.363), Testing loss = 2.747 (acc: 0.352), time 6.8s
# Epoch 26: Training loss = 0.079 (acc: 0.984), Validation loss = 2.844 (acc: 0.348), Testing loss = 2.817 (acc: 0.350), time 6.9s
# Epoch 27: Training loss = 0.029 (acc: 1.000), Validation loss = 2.984 (acc: 0.349), Testing loss = 2.982 (acc: 0.347), time 6.8s
# Epoch 28: Training loss = 0.027 (acc: 0.998), Validation loss = 3.041 (acc: 0.345), Testing loss = 3.013 (acc: 0.344), time 6.8s
# Epoch 29: Training loss = 0.021 (acc: 1.000), Validation loss = 3.126 (acc: 0.345), Testing loss = 3.094 (acc: 0.346), time 6.9s
# Epoch 30: Training loss = 0.037 (acc: 0.990), Validation loss = 3.420 (acc: 0.334), Testing loss = 3.363 (acc: 0.344), time 6.9s
# Epoch 31: Training loss = 0.068 (acc: 0.980), Validation loss = 3.232 (acc: 0.345), Testing loss = 3.249 (acc: 0.337), time 7.0s
# Epoch 32: Training loss = 0.049 (acc: 0.988), Validation loss = 3.636 (acc: 0.350), Testing loss = 3.589 (acc: 0.357), time 6.8s
# Epoch 33: Training loss = 0.022 (acc: 1.000), Validation loss = 3.232 (acc: 0.337), Testing loss = 3.232 (acc: 0.337), time 6.8s
# Epoch 34: Training loss = 0.022 (acc: 0.996), Validation loss = 3.309 (acc: 0.355), Testing loss = 3.273 (acc: 0.355), time 6.7s
# Epoch 35: Training loss = 0.008 (acc: 1.000), Validation loss = 3.342 (acc: 0.353), Testing loss = 3.320 (acc: 0.350), time 6.6s
# Epoch 36: Training loss = 0.008 (acc: 1.000), Validation loss = 3.358 (acc: 0.350), Testing loss = 3.365 (acc: 0.348), time 6.6s
# Epoch 37: Training loss = 0.005 (acc: 1.000), Validation loss = 3.483 (acc: 0.358), Testing loss = 3.434 (acc: 0.361), time 6.6s
# Epoch 38: Training loss = 0.030 (acc: 0.992), Validation loss = 3.778 (acc: 0.350), Testing loss = 3.752 (acc: 0.351), time 6.5s
# Epoch 39: Training loss = 0.017 (acc: 1.000), Validation loss = 3.448 (acc: 0.332), Testing loss = 3.425 (acc: 0.332), time 6.8s
# Epoch 40: Training loss = 0.009 (acc: 0.998), Validation loss = 3.591 (acc: 0.351), Testing loss = 3.549 (acc: 0.356), time 6.6s
# Epoch 41: Training loss = 0.012 (acc: 0.996), Validation loss = 3.554 (acc: 0.352), Testing loss = 3.505 (acc: 0.352), time 6.6s
# Epoch 42: Training loss = 0.009 (acc: 1.000), Validation loss = 3.668 (acc: 0.355), Testing loss = 3.597 (acc: 0.358), time 6.6s
# Epoch 43: Training loss = 0.012 (acc: 0.998), Validation loss = 3.589 (acc: 0.334), Testing loss = 3.551 (acc: 0.334), time 6.6s
# Epoch 44: Training loss = 0.003 (acc: 1.000), Validation loss = 3.619 (acc: 0.349), Testing loss = 3.563 (acc: 0.350), time 6.6s
# Epoch 45: Training loss = 0.009 (acc: 0.998), Validation loss = 3.770 (acc: 0.349), Testing loss = 3.717 (acc: 0.353), time 6.6s
# Epoch 46: Training loss = 0.011 (acc: 0.998), Validation loss = 3.716 (acc: 0.354), Testing loss = 3.664 (acc: 0.350), time 6.6s
# Epoch 47: Training loss = 0.006 (acc: 1.000), Validation loss = 3.755 (acc: 0.338), Testing loss = 3.693 (acc: 0.342), time 6.6s
# Epoch 48: Training loss = 0.005 (acc: 1.000), Validation loss = 3.633 (acc: 0.349), Testing loss = 3.585 (acc: 0.351), time 6.8s
# Epoch 49: Training loss = 0.002 (acc: 1.000), Validation loss = 3.663 (acc: 0.352), Testing loss = 3.622 (acc: 0.355), time 6.6s
# Epoch 50: Training loss = 0.003 (acc: 1.000), Validation loss = 3.872 (acc: 0.345), Testing loss = 3.829 (acc: 0.345), time 6.6s

# %% [markdown]
# # Evaluation

# %%
import matplotlib.pyplot as plt

epochs_x = list(range(1, 51))

plt.plot(epochs_x, history_baseline["train_loss"], "#FFC20A", label="supervised")
plt.plot(epochs_x, history["train_loss"], "#0C7BDC", label="semi-supervised")
plt.title("Training Loss (50 epochs)")
plt.legend()
plt.show()

plt.plot(epochs_x, history["train_acc"], "#0C7BDC", label="semi-supervised")
plt.plot(epochs_x, history_baseline["train_acc"], "#FFC20A", label="supervised")
plt.title("Training Accuracy")
plt.legend()
plt.show()

plt.plot(epochs_x, history_baseline["val_loss"], "#FFC20A", label="supervised")
plt.plot(epochs_x, history["val_loss"], "#0C7BDC", label="semi-supervised")
plt.title("Validation Loss (50 epochs)")
plt.legend()
plt.show()

plt.plot(epochs_x, history["val_acc"], "#0C7BDC", label="semi-supervised")
plt.plot(epochs_x, history_baseline["val_acc"], "#FFC20A", label="supervised")
plt.title("Validation Accuracy")
plt.legend()
plt.show()

plt.plot(epochs_x, history_baseline["test_loss"], "#FFC20A", label="supervised")
plt.plot(epochs_x, history["test_loss"], "#0C7BDC", label="semi-supervised")
plt.title("Testing Loss (50 epochs)")
plt.legend()
plt.show()

plt.plot(epochs_x, history["test_acc"], "#0C7BDC", label="semi-supervised")
plt.plot(epochs_x, history_baseline["test_acc"], "#FFC20A", label="supervised")
plt.title("Testing Accuracy")
plt.legend()
plt.show()

# %%
print("The total test accuracy is: %.2f%%" %(history_baseline["test_acc"][-1]*100))
# Out:
# The total test accuracy is: 37.30%

# %% [markdown]
# # Confusion Matrix

# %%
m = nn.Softmax(dim=1)

def confusionMatrix(net, device, loader, predictedLabel, actualLabel):
    
    net.eval()
    
    with torch.no_grad():
        for i, (x, y) in enumerate(loader):
            
            fx = net(x.to(device))
            
            softout = m(fx.to(device))

            for k in range(len(softout)):
                value, indx = torch.max(softout[k], 0)
                predictedLabel.append(indx.cpu().detach().numpy().item())
                actualLabel.append(y.to(device)[k].cpu().detach().numpy().item())             
        
    return predictedLabel, actualLabel

def plot_confusion_matrix(df_confusion, title='Confusion matrix', cmap=plt.cm.gray_r):
    plt.matshow(df_confusion, cmap=cmap) # imshow
    #plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(df_confusion.columns))
    plt.xticks(tick_marks, df_confusion.columns, rotation=45)
    plt.yticks(tick_marks, df_confusion.index)
    #plt.tight_layout()
    plt.ylabel(df_confusion.index.name)
    plt.xlabel(df_confusion.columns.name)

# %%
training_pred, validation_pred, testing_pred = [], [], []
training_actual, validation_actual, testing_actual = [], [], []

training_pred, training_actual = confusionMatrix(encoder_post, device, train_loader, training_pred, training_actual)
validation_pred, validation_actual = confusionMatrix(encoder_post, device, valid_loader, validation_pred, validation_actual)
testing_pred, testing_actual = confusionMatrix(encoder_post, device, test_loader, testing_pred, testing_actual)

training_actual = pd.Series(training_actual, name='Training Actual')
training_pred = pd.Series(training_pred, name='Training Predicted')
df_confusion_training = pd.crosstab(training_actual, training_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_conf_norm_training = df_confusion_training / df_confusion_training.sum(axis=1)

validation_actual = pd.Series(validation_actual, name='Validation Actual')
validation_pred = pd.Series(validation_pred, name='Validation Predicted')
df_confusion_validation = pd.crosstab(validation_actual, validation_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_conf_norm_validation = df_confusion_validation / df_confusion_validation.sum(axis=1)

testing_actual = pd.Series(testing_actual, name='Testing Actual')
testing_pred = pd.Series(testing_pred, name='Testing Predicted')
df_confusion_testing = pd.crosstab(testing_actual, testing_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
df_conf_norm_testing = df_confusion_testing / df_confusion_testing.sum(axis=1)


plot_confusion_matrix(df_conf_norm_training)

plot_confusion_matrix(df_conf_norm_validation)

plot_confusion_matrix(df_conf_norm_testing)
